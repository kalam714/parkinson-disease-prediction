# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('data.csv')
data.shape
# Out:
# (77, 31)

# %%
data.isnull()
# Out:
#     Unnamed: 0  no_strokes_st  no_strokes_dy  speed_st  speed_dy  \
# 0        False          False          False     False     False
# 1        False          False          False     False     False
# 2        False          False          False     False     False
# 3        False          False          False     False     False
# 4        False          False          False     False     False
# ..         ...            ...            ...       ...       ...
# 72       False          False          False     False     False
# 73       False          False          False     False     False
# 74       False          False          False     False     False
# 75       False          False          False     False     False
# 76       False          False          False     False     False
#
#     magnitude_vel_st  magnitude_horz_vel_st  magnitude_vert_vel_st  \
# 0              False                  False                  False
# ...

# %%
data.describe().T
# Out:
#                         count         mean          std  min         25%  \
# Unnamed: 0               77.0    38.000000    22.371857  0.0   19.000000
# no_strokes_st            77.0    12.753247    34.688143  0.0    2.000000
# no_strokes_dy            77.0     9.012987    23.865023  0.0    2.000000
# speed_st                 77.0     0.003215     0.008312  0.0    0.000014
# speed_dy                 77.0     0.003050     0.007464  0.0    0.000012
# magnitude_vel_st         77.0     0.140580     0.103393  0.0    0.068614
# magnitude_horz_vel_st    77.0     0.093403     0.071022  0.0    0.045253
# magnitude_vert_vel_st    77.0     0.084502     0.064026  0.0    0.041868
# magnitude_vel_dy         77.0     0.162754     0.149519  0.0    0.064987
# magnitude_horz_vel_dy    77.0     0.107696     0.100618  0.0    0.040963
# magnitude_vert_vel_dy    77.0     0.098040     0.092671  0.0    0.041055
# magnitude_acc_st         77.0     0.000776     0.001162  0.0    0.000282
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              77 non-null     int64
#  1   no_strokes_st           77 non-null     float64
#  2   no_strokes_dy           77 non-null     float64
#  3   speed_st                77 non-null     float64
#  4   speed_dy                77 non-null     float64
#  5   magnitude_vel_st        77 non-null     float64
#  6   magnitude_horz_vel_st   77 non-null     float64
#  7   magnitude_vert_vel_st   77 non-null     float64
#  8   magnitude_vel_dy        77 non-null     float64
#  9   magnitude_horz_vel_dy   77 non-null     float64
#  10  magnitude_vert_vel_dy   77 non-null     float64
#  11  magnitude_acc_st        77 non-null     float64
#  12  magnitude_horz_acc_st   77 non-null     float64
#  13  magnitude_vert_acc_st   77 non-null     float64
# ...

# %%
data=data.drop(['Unnamed: 0'],axis=1)
data.head()
# Out:
#    no_strokes_st  no_strokes_dy  speed_st  speed_dy  magnitude_vel_st  \
# 0           12.0            2.0  0.000293  0.000431          0.061342
# 1            4.0            6.0  0.000286  0.000281          0.119159
# 2            4.0            4.0  0.000278  0.000277          0.113889
# 3            4.0            4.0  0.000286  0.000275          0.154621
# 4            2.0            2.0  0.000279  0.000270          0.060058
#
#    magnitude_horz_vel_st  magnitude_vert_vel_st  magnitude_vel_dy  \
# 0               0.038319               0.039050          0.084891
# 1               0.077012               0.074216          0.160497
# 2               0.071547               0.073336          0.191965
# 3               0.101146               0.096300          0.152413
# 4               0.039449               0.036737          0.081577
#
#    magnitude_horz_vel_dy  magnitude_vert_vel_dy  ...  magnitude_horz_jerk_dy  \
# ...

# %%
data["target"].value_counts()
# Out:
# 1.0    62
# 0.0    15
# Name: target, dtype: int64

# %%
# target countplot
count=sns.countplot(x="target", data = data)

# %%
# Histogram of each feature
import itertools

col = data.columns[:16]
plt.subplots(figsize = (20, 15))
length = len(col)

for i, j in itertools.zip_longest(col, range(length)):
    plt.subplot((length/2), 2, j + 1)
    plt.subplots_adjust(wspace = 0.1,hspace = 0.5)
    data[i].hist(bins = 15)
    '\n'
    plt.title(i)
    
plt.show()
# Out:
# <ipython-input-9-4b4ec1c750e6>:9: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot((length/2), 2, j + 1)

# %%
import itertools

col = data.columns[17:27]
plt.subplots(figsize = (20, 15))
length = len(col)

for i, j in itertools.zip_longest(col, range(length)):
    plt.subplot((length/2), 2, j + 1)
    plt.subplots_adjust(wspace = 0.1,hspace = 0.5)
    data[i].hist(bins = 15)
    '\n'
    plt.title(i)
    
plt.show()
# Out:
# <ipython-input-27-e582365c5cac>:8: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot((length/2), 2, j + 1)

# %%
import itertools

col = data.columns[30:40]
plt.subplots(figsize = (20, 15))
length = len(col)

for i, j in itertools.zip_longest(col, range(length)):
    plt.subplot((length/2), 2, j + 1)
    plt.subplots_adjust(wspace = 0.1,hspace = 0.5)
    data[i].hist(bins = 15)
    '\n'
    plt.title(i)
    
plt.show()
# Out:
# <ipython-input-11-dcfb15927c93>:8: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot((length/2), 2, j + 1)

# %%
# # Scatter plot matrix 
# from pandas.plotting import scatter_matrix
# scatter_matrix(data, figsize = (50, 50));

# %%
# sns.pairplot(data = data, hue = 'target')
# plt.show()

# %%
# Heatmap
sns.heatmap(data.corr(), annot = True)
plt.show()

# %%
sns.set(style="whitegrid")
data.boxplot(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(4,2)})
sns.boxplot(x=data['no_strokes_st'])
plt.show()
